# %%
import pandas as pd
a=pd.read_csv("student_scores (3).csv")
a.head()
# Out:
#    study_hours  online_hours  self_study  attendance  sleep_hours  score
# 0          2.0           1.5         1.0          60          8.0     38
# 1          2.5           2.0         1.5          62          7.8     42
# 2          3.0           2.5         2.0          65          7.6     46
# 3          3.5           3.0         2.5          68          7.5     50
# 4          4.0           3.5         3.0          70          7.4     55

# %%
a.isnull().sum()
# Out:
# study_hours     0
# online_hours    0
# self_study      0
# attendance      0
# sleep_hours     0
# score           0
# dtype: int64

# %%
#top 3 scores
top3=a.sort_values(by=['score'], ascending=False)
top3.head(3)
# Out:
#     study_hours  online_hours  self_study  attendance  sleep_hours  score
# 19         11.5          11.0        10.5          99          5.9     98
# 18         11.0          10.5        10.0          98          6.0     97
# 17         10.5          10.0         9.5          97          6.1     96

# %%
a.aggregate({'score':['mean']})
# Out:
#       study_hours
# mean        6.725

# %%
a.aggregate({'study_hours':['mean']})
# Out:
#       study_hours
# mean        6.725

# %%
import matplotlib.pyplot as plt
plt.figure()
#bar graph
plt.bar(range(len(a['score'])), a['score'])
plt.show()

# %%
# Histogram
plt.hist(a['score'])
plt.show()

# %%
# Box plot
plt.boxplot(a['score'])
plt.show()

# %%
plt.pie(a['score'])
plt.show()
